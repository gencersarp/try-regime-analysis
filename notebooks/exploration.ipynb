# %% [markdown]
# # TRY Regime Analysis Exploration
#
# This notebook explores the TRY FX regimes and intervention metrics.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src.data.loader import DataLoader
from src.features.builder import FeatureBuilder
from src.models.regime_detector import RegimeDetector
from src.analysis.intervention import InterventionInference
from src.visualization.plots import plot_regime_timeline, plot_intervention_analysis

# %%
loader = DataLoader()
raw_data = loader.get_all_data(cache=True)
builder = FeatureBuilder(raw_data)
df = builder.build()

# %%
detector = RegimeDetector(n_components=3)
regimes = detector.fit_predict(df)
df['regime'] = regimes

# %%
plot_regime_timeline(df, regimes)
